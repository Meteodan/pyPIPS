# %%
import os
import glob
import numpy as N

# %%
rawdatadir = '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/'
converteddatadir = '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/converted/'

# %%
filelistraw = glob.glob(rawdatadir+'*TenHz*.dat')
print filelistraw
filelistconverted = glob.glob(converteddatadir+'*TenHz*.dat')
# Out:
# ['/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz0.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz10.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz100.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1000.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1001.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1002.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1003.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1004.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1005.da
# ...

# %%
#temp = sorted(zip(filelistraw,filelistconverted), key=lambda pair: os.path.getmtime(pair[0]))
tuplist = [tup for tup in sorted(zip(filelistraw,filelistconverted), key=lambda pair: os.path.getmtime(pair[0]))]
filelistraw_sorted = [pair[0] for pair in tuplist]
filelistconverted_sorted = [pair[1] for pair in tuplist]
#filelistraw_sorted = [y for (y,x) in sorted(zip(filelistraw,filelistconverted), key=lambda pair: os.path.getctime(pair[0]))]
#filelistconverted_sorted = [x for (y,x) in sorted(zip(filelistraw,filelistconverted), key=lambda pair: os.path.getctime(pair[0]))]
#filelistraw_sorted = [x for x in sorted(filelistraw,key=lambda y: os.path.getctime(y))]
print filelistraw_sorted
# Out:
# ['/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz0.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz1.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz2.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz3.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz4.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz5.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz6.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz7.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz8.dat', '/Users/ddawson/Dropbox/VORTEXSE/PIPS_data/2017fieldprogram/PIPS2A_FMCW/raw/Parsivel_TenHz9.dat', '/Users/ddawson/D
# ...

# %%
from datetime import date
datelist = [date.fromtimestamp(os.path.getmtime(x)) for x in filelistraw_sorted]
print datelist
# Out:
# [datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(2017, 3, 24), datetime.date(201
# ...

# %%
import itertools
import shutil
for key,group in itertools.groupby(zip(datelist,filelistconverted_sorted),lambda x: x[0]):
    keystring = key.strftime('%m%d%y')
    keydir = converteddatadir+'/'+keystring
    print keystring
#     if (not os.path.exists(keydir)):
#         os.makedirs(keydir)
#     for path in group:
#         #print path[1]
#         shutil.copy2(path[1],keydir)
# Out:
# 032417
# 032517
# 032617
# 032717
# 032817
# 032917
# 033017
# 033117
